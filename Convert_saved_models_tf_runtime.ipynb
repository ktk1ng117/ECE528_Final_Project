# %%
import pandas as pd
import os, time
import numpy as np
import tensorflow as tf
import tensorflow_model_optimization as tfmot
# Out:
# WARNING:tensorflow:From c:\Graduate_School\Fall_2025\ECE528\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Load the model in 2.19

# %%
loaded_model = tf.keras.models.load_model(r'model_MobileNetV3_original.keras')
tf.saved_model.save(loaded_model, "model_MobileNetV3_original")
# Out:
# INFO:tensorflow:Assets written to: model_MobileNetV3_original\assets
# INFO:tensorflow:Assets written to: model_MobileNetV3_original\assets

# %%
loaded_model = tf.keras.models.load_model(r'model_MobileNetV3.keras')
tf.saved_model.save(loaded_model, "model_MobileNetV3_grey")
# Out:
# INFO:tensorflow:Assets written to: model_MobileNetV3_grey\assets
# INFO:tensorflow:Assets written to: model_MobileNetV3_grey\assets

# %%
loaded_model = tf.keras.models.load_model(r'best_saved_model')
model.save('model_EfficientNetb0_grey.keras')
print("Original model in Mb:", os.path.getsize(loaded_model) / float(2**20))
# Out:
# Original model in Mb: 0.00390625

# %% [markdown]
# # Run in 2.14 to quantize

# %%
def convert_model(original_model_name, quantized_model_name):
    loaded_model = tf.saved_model.load(original_model_name)
    converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()
    with open(quantized_model_name, 'wb') as f:
        f.write(tflite_model)

# %%
convert_model("model_EfficientNetb0_original", 'model_EfficientNetb0_original_quantized.tflite')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpahsmgm3z\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpahsmgm3z\assets

# %%
convert_model("model_EfficientNetb0_grey", 'model_EfficientNetb0_grey_quantized.tflite')

# %%
convert_model("model_MobileNetV3_grey", 'model_MobileNetV3_grey_quantized.tflite')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmprij_67n6\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmprij_67n6\assets

# %%
convert_model("model_MobileNetV3_original", 'model_MobileNetV3_original_quantized.tflite')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmp_nfghbi6\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmp_nfghbi6\assets

# %%
convert_model("model_ResNet50_grey", 'model_ResNet50_grey_quantized.tflite')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpra_v6k02\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpra_v6k02\assets

# %%
convert_model("model_ResNet50_original", 'model_ResNet50_original_quantized.tflite')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpymo0yo0y\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpymo0yo0y\assets

# %%
convert_model("best_saved_model", 'model_yolo11_grey_quantized.tflite')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmphs1238q8\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmphs1238q8\assets

# %%
convert_model("best_saved_model", 'model_yolo11_original_quantized.tflite')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmp1tztdpb0\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmp1tztdpb0\assets

# %%
loaded_model = tf.saved_model.load("model_EfficientNetb0")
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()
with open('model_EfficientNetb0_quantized.tflite', 'wb') as f:
    f.write(tflite_model)
