# %%
import pandas as pd
import os, time
import numpy as np
from tensorflow.keras.applications import EfficientNetB0
import tensorflow as tf
from tensorflow.keras import layers, models
import tensorflow_model_optimization as tfmot
from tensorflow.keras.callbacks import EarlyStopping

# %%
#EfficientNetb0
data_dir = "data/north_american_predators/greyscale_downsampled_split/train"
dataset_train = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(224, 224),
  batch_size=64)

data_dir = "data/north_american_predators/greyscale_downsampled_split/val"
dataset_val = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(224, 224),
  batch_size=64)

data_dir = "data/north_american_predators/greyscale_downsampled_split/test"
dataset_test = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(224, 224),
  batch_size=64)
# Out:
# Found 13823 files belonging to 8 classes.
# Found 3454 files belonging to 8 classes.
# Found 4317 files belonging to 8 classes.

# %%
def evaluate_model_tflite(interpreter, dataset):
    #List of dictionaries
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    correct = 0
    total = 0

    for images, labels in dataset:
        input_type = input_details[0]['dtype']
        # Convert the batch to the correct type
        images = images.numpy().astype(input_type)
        labels = labels.numpy()
        
        for i in range(images.shape[0]):
            test_image = np.expand_dims(images[i], axis=0)
            #From Tensorflow API Docs
            interpreter.set_tensor(input_details[0]['index'], test_image)
            interpreter.invoke()
            output = interpreter.get_tensor(output_details[0]['index'])
            #Gets the most prominent class
            pred = np.argmax(output)
            if pred == labels[i]:
                correct += 1
            total += 1

    accuracy = correct / total
    return accuracy

# %%
#Issue with Keras 3.11. Must load weights after the fact
base_model = tf.keras.applications.EfficientNetB0(weights=None,
                                                input_shape=(224,224,3),
                                                include_top=False)
base_model.load_weights("efficientnetb0_notop.h5")
 
base_model.trainable = False

inputs = tf.keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
outputs = tf.keras.layers.Dense(8, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
)
early_stop = EarlyStopping(
    monitor='val_sparse_categorical_accuracy',
    patience=5,
    restore_best_weights=True,
    mode='max'
)

start_time = time.time()
model.fit(dataset_train, epochs=100, validation_data=dataset_val, callbacks=[early_stop])
end_time = time.time()
training_duration = end_time - start_time
print(f"Training time: {training_duration:.2f} seconds")
# Out:
# Epoch 1/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 102s 457ms/step - loss: 0.3301 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.3606 - val_sparse_categorical_accuracy: 0.8619
# Epoch 2/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 95s 438ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.3297 - val_sparse_categorical_accuracy: 0.8796
# Epoch 3/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 93s 431ms/step - loss: 0.0642 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.3296 - val_sparse_categorical_accuracy: 0.8830
# Epoch 4/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 428ms/step - loss: 0.0508 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.3265 - val_sparse_categorical_accuracy: 0.8856
# Epoch 5/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 95s 440ms/step - loss: 0.0439 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.3465 - val_sparse_categorical_accuracy: 0.8836
# Epoch 6/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 93s 432ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9884 - val_loss: 0.3514 - val_sparse_categorical_accuracy: 0.8851
# Epoch 7/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 428ms/step - loss: 0.0327 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.3589 - val_sparse_categorical_accuracy: 0.8848
# Epoch 8/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 428ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.3796 - val_sparse_categorical_accuracy: 0.8819
# Epoch 9/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 93s 431ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.3713 - val_sparse_categorical_accuracy: 0.8877
# Epoch 10/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 427ms/step - loss: 0.0268 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.4212 - val_sparse_categorical_accuracy: 0.8738
# Epoch 11/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 425ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.4096 - val_sparse_categorical_accuracy: 0.8787
# Epoch 12/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 425ms/step - loss: 0.0240 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.4147 - val_sparse_categorical_accuracy: 0.8787
# Epoch 13/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 426ms/step - loss: 0.0220 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4041 - val_sparse_categorical_accuracy: 0.8825
# Epoch 14/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 92s 425ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.4587 - val_sparse_categorical_accuracy: 0.8735
# Training time: 1307.05 seconds

# %%
start_time = time.time()
test_loss, test_acc = model.evaluate(dataset_test, verbose=0)
end_time = time.time()
training_duration = end_time - start_time
print(f"Evaluation time: {training_duration:.2f} seconds")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Evaluation time: 23.00 seconds
# Test Loss: 0.3455
# Test Accuracy: 89.14%

# %%
model.save('model_EfficientNetb0_grey.keras')
print("Baseline model in Mb:", os.path.getsize(r'model_EfficientNetb0_grey.keras') / float(2**20))
# Out:
# Baseline model in Mb: 16.36735248565674

# %%
loaded_model = tf.keras.models.load_model(r'model_EfficientNetb0_grey.keras')
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()
with open('model_EfficientNetb0_quantized_grey.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpx6oy5nxo\assets
# INFO:tensorflow:Assets written to: C:\Users\kingk\AppData\Local\Temp\tmpx6oy5nxo\assets
# Saved artifact at 'C:\Users\kingk\AppData\Local\Temp\tmpx6oy5nxo'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_5')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   2955461329168: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2955461328976: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2952125662224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125661264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125670288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125663760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125670864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125671440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125672016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125671248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125671824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125672400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125672976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125673360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125673168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125673936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125672592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125674704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125674896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125674320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125673552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125675280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125675856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125674512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125674128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125675664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125676240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952125676816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2952